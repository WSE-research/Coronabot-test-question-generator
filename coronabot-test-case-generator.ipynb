# %% [markdown]
# # Question Generator for Coronabot

# %% [markdown]
# ## Define question templates and required parameters

# %%
templates = [
        {
            "questions": [
                "What was the death toll in [PLACE_LABEL] during the last [MONTH]?",
                "How many people died in [PLACE_LABEL] last [MONTH]?",
                "How many deaths were reported last [MONTH] in [PLACE_LABEL]?",
                "covid deaths in [PLACE_LABEL] last [MONTH]",
                "how many deaths did [PLACE_LABEL] have last [MONTH]?"
            ],
            "parameters": {
                "QUESTION_CLASS": "death_location_time",
                "CONTAINS_TIME": True,
                "CONTAINS_PLACE": True
            }
        },
        {
            "questions": [
                "What was the death toll in [PLACE_LABEL] during [MONTH] of [YEAR]?",
                "How many people died in [PLACE_LABEL] in [MONTH] [YEAR]?",
                "How many deaths were reported in [PLACE_LABEL] in [MONTH] [YEAR]?",
                "covid deaths in [PLACE_LABEL] in [MONTH] of [YEAR]",
                "how many deaths did [PLACE_LABEL] have in [MONTH] [YEAR]?"
            ],
            "parameters": {
                "QUESTION_CLASS": "death_location_time",
                "CONTAINS_TIME": True,
                "CONTAINS_PLACE": True
            }
        },
        {
            "questions": [
                "How many infections were there in [PLACE_LABEL] in [MONTH] [YEAR]?",
                "In [MONTH] [YEAR], how many people were infected in [PLACE_LABEL]?",
                "Give me the number of cases in [PLACE_LABEL] during [MONTH] [YEAR]!",
                "How many cases of Covid did [PLACE_LABEL] report in [MONTH] [YEAR]?",
                "infections in [MONTH] [YEAR] in [PLACE_LABEL]"
            ],
            "parameters": {
                "QUESTION_CLASS": "infection_location_time",
                "CONTAINS_TIME": True,
                "CONTAINS_PLACE": True
            }
        },
        {
            "questions": [
                "What was the number of incidents of [PLACE_LABEL] in [YEAR]?",
                "In [YEAR], how many people were infected in [PLACE_LABEL]?",
                "What was the number of infections during [YEAR] in [PLACE_LABEL]?"
            ],
            "parameters": {
                "QUESTION_CLASS": "infection_location_time",
                "CONTAINS_TIME": True,
                "CONTAINS_PLACE": True
            }
        },
        {
            "questions": [
                "How many people died in [PLACE_LABEL]?",
                "How many deaths were reported in [PLACE_LABEL]?",
                "covid deaths in [PLACE_LABEL]",
                "What is the current death toll in [PLACE_LABEL]?"
            ],
            "parameters": {
                "QUESTION_CLASS": "death_location",
                "CONTAINS_TIME": False,
                "CONTAINS_PLACE": True
            }
        },       
        {
            "questions": [
                "How many people died during [MONTH] [YEAR]?",
                "How many deaths were reported in [MONTH] of [YEAR]?",
                "covid deaths on the fith of [MONTH] [YEAR]",
                "What was the death toll during [MONTH] [YEAR]?",
                "number of deaths from first of [MONTH] until 15th of [MONTH] [YEAR]"
            ],
            "parameters": {
                "QUESTION_CLASS": "death_time",
                "CONTAINS_TIME": True,
                "CONTAINS_PLACE": False
            }
        }, 
        {
            "questions": [
                "How many people died during last [MONTH]?",
                "How many deaths were reported in last [MONTH]?",
                "covid deaths on the fith of last [MONTH]",
                "What was the death toll last [MONTH]?",
                "number of deaths from the first until the 15th of last [MONTH]"
            ],
            "parameters": {
                "QUESTION_CLASS": "death_time",
                "CONTAINS_TIME": True,
                "CONTAINS_PLACE": False
            }
        },
        {
            "questions": [
                "How many cases were reported on the first of [MONTH] [YEAR]?",
                "What was the number of infections during [MONTH] [YEAR]?",
                "infections between the first of [MONTH] [YEAR] and the 28th of [MONTH] [YEAR]?",
                "How many people were infected with Covid-19 in [MONTH] [YEAR]",
                "corona cases in [MONTH] [YEAR]"
            ],
            "parameters": {
                "QUESTION_CLASS": "infection_time",
                "CONTAINS_TIME": True,
                "CONTAINS_PLACE": False
            }
        }, 
        {
            "questions": [
                "How many cases were reported on the first of last [MONTH]?",
                "What was the number of infections last [MONTH]?",
                "infections between the first and 28th of last [MONTH]?",
                "How many people were infected with Covid-19 last [MONTH]",
                "corona cases last [MONTH]"
            ],
            "parameters": {
                "QUESTION_CLASS": "infection_time",
                "CONTAINS_TIME": True,
                "CONTAINS_PLACE": False
            }
        },
        {
            "questions": [
                "Infections in [PLACE_LABEL] and Kiel?",
                "Cases in [PLACE_LABEL]?",
                "How many people have been infected in [PLACE_LABEL] in total?",
                "[PLACE_LABEL] corona cases",
                "give me the number of infections in [PLACE_LABEL]"
            ],
            "parameters": {
                "QUESTION_CLASS": "infection_location",
                "CONTAINS_TIME": False,
                "CONTAINS_PLACE": True
            }
        }        
]

max_number_of_locations = 1000 # German districts: 400, but different labels are available
max_number_of_used_templates = 200 
max_number_of_generated_questions = 500 
parameters = {
    "MONTH": ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"],
    "YEAR": [2020, 2021],
    "PLACE_LABEL": [],
    "PLACE_URL": [],
    "DISTRICT_URL": [],
    "LANGUAGE": ["en"]
}

# %% [markdown]
# ## SPARQL query to retrieve places in Germany

# %%
any_place_with_population_query = """
# get any kind of places 

PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX p: <http://www.wikidata.org/prop/>
PREFIX ps: <http://www.wikidata.org/prop/statement/>
PREFIX pq: <http://www.wikidata.org/prop/qualifier/>

SELECT DISTINCT ?district_url ?district_label ?place_url ?place_label WHERE {
  # ?district_url p:P31/ps:P31/wdt:P279* wd:Q106658 .
  # ?district_url wdt:P17 wd:Q183 .
  # ?district_url rdfs:label ?district_label .
  # ?place_url wdt:P1082 ?population.
  # ?place_url rdfs:label ?place_label .
  # ?place_url wdt:P131* ?district_url
  FILTER (LANG(?place_label) = "en").
  FILTER (LANG(?district_label) = "en").
} 
LIMIT """ + str(max_number_of_locations) + """
"""

only_district_query = """
# get all districts

PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX p: <http://www.wikidata.org/prop/>
PREFIX ps: <http://www.wikidata.org/prop/statement/>
PREFIX pq: <http://www.wikidata.org/prop/qualifier/>

SELECT DISTINCT ?district_url ?district_label ?place_url ?place_label WHERE {
  # ?district_url p:P31/ps:P31/wdt:P279* wd:Q106658 .
  # ?district_url wdt:P17 wd:Q183 .
  # ?district_url rdfs:label ?district_label .
  FILTER (LANG(?district_label) = "en").
  BIND(?district_url AS ?place_url) . # district is the place here
  BIND(?district_label AS ?place_label) . # district is the place here
} 
LIMIT """ + str(max_number_of_locations) + """
"""

# places_query = any_place_with_population_query
places_query = only_district_query

# %% [markdown]
# ### add places from Wikidata

# %%
from pprint import pprint
from SPARQLWrapper import SPARQLWrapper, JSON # https://sparqlwrapper.readthedocs.io/en/latest/main.html

sparql = SPARQLWrapper("https://query.wikidata.org/bigdata/namespace/wdq/sparql")
sparql.setQuery(places_query)
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
# pprint(results)

place_values = []
place_names_map = {}
place_to_district_map = {}
place_to_district_label_map = {}

for result in results["results"]["bindings"]:
    # print(result["label"]["value"], result["district"]["value"])
    place_url = result["place_url"]["value"]
    place_label = result["place_label"]["value"]
    district_url = result["district_url"]["value"]
    district_label = result["district_label"]["value"]

    place_values.append(place_label)
    place_names_map[place_label] = place_url
    place_to_district_map[place_url] = district_url
    place_to_district_label_map[place_url] = district_label

parameters["PLACE_LABEL"] = place_values
parameters["PLACE_URL"] = place_names_map
parameters["DISTRICT_URL"] = place_to_district_map
parameters["DISTRICT_LABEL"] = place_to_district_label_map

pprint(parameters["PLACE_URL"])
number=len(parameters["PLACE_LABEL"])
print(f"number of found places: {number}")
# Out:
# {'Aachen': 'http://www.wikidata.org/entity/Q7379734',
#  'Aachen cities region': 'http://www.wikidata.org/entity/Q6272',
#  'Ahaus District': 'http://www.wikidata.org/entity/Q878419',
#  'Ahrweiler': 'http://www.wikidata.org/entity/Q8596',
#  'Aichach': 'http://www.wikidata.org/entity/Q1756892',
#  'Aichach-Friedberg': 'http://www.wikidata.org/entity/Q10415',
#  'Alb-Donau-Kreis': 'http://www.wikidata.org/entity/Q8221',
#  'Alfeld': 'http://www.wikidata.org/entity/Q1803052',
#  'Alsfeld': 'http://www.wikidata.org/entity/Q1803054',
#  'Altena District': 'http://www.wikidata.org/entity/Q1803056',
#  'Altenburger Land': 'http://www.wikidata.org/entity/Q7888',
#  'Altenkirchen district': 'http://www.wikidata.org/entity/Q8608',
#  'Altlandkreis Kulmbach': 'http://www.wikidata.org/entity/Q105729117',
#  'Altlandkreis Lichtenfels': 'http://www.wikidata.org/entity/Q105744572',
#  'Altmarkkreis Salzwedel': 'http://www.wikidata.org/entity/Q6061',
#  'Altötting': 'http://www.wikidata.org/entity/Q10533',
#  'Alzey-Worms': 'http://www.wikidata.org/entity/Q8566',
#  'Amberg (Germany : Landkreis)': 'http://www.wikidata.org/entity/Q1718802',
#  'Amberg-Sulzbach': 'http://www.wikidata.org/entity/Q10421',
#  'Ammerland': 'http://www.wikidata.org/entity/Q5947',
#  'Anhalt-Bitterfeld': 'http://www.wikidata.org/entity/Q6071',
#  'Anhalt-Zerbst': 'http://www.wikidata.org/entity/Q114369',
#  'Annaberg': 'http://www.wikidata.org/entity/Q20221',
#  'Ansbach': 'http://www.wikidata.org/entity/Q10454',
#  'Arnsberg District': 'http://www.wikidata.org/entity/Q600902',
#  'Aschaffenburg': 'http://www.wikidata.org/entity/Q10471',
#  'Aschersleben-Staßfurt': 'http://www.wikidata.org/entity/Q114225',
#  'Aue-Schwarzenberg': 'http://www.wikidata.org/entity/Q20223',
#  'Augsburg': 'http://www.wikidata.org/entity/Q10414',
#  'Aurich': 'http://www.wikidata.org/entity/Q5929',
#  'Bad Aibling county': 'http://www.wikidata.org/entity/Q1803069',
#  'Bad Doberan District': 'http://www.wikidata.org/entity/Q9627',
#  'Bad Dürkheim': 'http://www.wikidata.org/entity/Q8557',
#  'Bad Kissingen': 'http://www.wikidata.org/entity/Q10466',
#  'Bad Kreuznach': 'http://www.wikidata.org/entity/Q8572',
#  'Bad Tölz': 'http://www.wikidata.org/entity/Q1803073',
#  'Bad Tölz-Wolfratshausen': 'http://www.wikidata.org/entity/Q10522',
#  'Balingen': 'http://www.wikidata.org/entity/Q1250365',
#  'Bamberg': 'http://www.wikidata.org/entity/Q10444',
#  'Barnim District': 'http://www.wikidata.org/entity/Q6115',
#  'Bautzen': 'http://www.wikidata.org/entity/Q20225',
#  'Bautzen District': 'http://www.wikidata.org/entity/Q571947',
#  'Bayreuth': 'http://www.wikidata.org/entity/Q10439',
#  'Beckum District': 'http://www.wikidata.org/entity/Q653282',
#  'Berchtesgaden': 'http://www.wikidata.org/entity/Q1517485',
#  'Berchtesgadener Land': 'http://www.wikidata.org/entity/Q10530',
#  'Bernburg': 'http://www.wikidata.org/entity/Q114157',
#  'Bernkastel-Wittlich': 'http://www.wikidata.org/entity/Q8585',
#  'Bersenbrück': 'http://www.wikidata.org/entity/Q1803084',
#  'Biberach district': 'http://www.wikidata.org/entity/Q8223',
#  'Bielefeld District': 'http://www.wikidata.org/entity/Q260884',
#  'Bingen': 'http://www.wikidata.org/entity/Q1803088',
#  'Birkenfeld': 'http://www.wikidata.org/entity/Q8575',
#  'Bitterfeld': 'http://www.wikidata.org/entity/Q114614',
#  'Bodenseekreis': 'http://www.wikidata.org/entity/Q8228',
#  'Bogen district': 'http://www.wikidata.org/entity/Q1449780',
#  'Bonn': 'http://www.wikidata.org/entity/Q1685614',
#  'Borken': 'http://www.wikidata.org/entity/Q6191',
#  'Brakel District': 'http://www.wikidata.org/entity/Q1787232',
#  'Brand-Erbisdorf (Germany : Landkreis)': 'http://www.wikidata.org/entity/Q1803095',
#  'Braunschweig': 'http://www.wikidata.org/entity/Q1803098',
#  'Breisgau-Hochschwarzwald': 'http://www.wikidata.org/entity/Q8195',
#  'Brilon District': 'http://www.wikidata.org/entity/Q1787239',
#  'Bruchsal': 'http://www.wikidata.org/entity/Q1803101',
#  'Burgdorf': 'http://www.wikidata.org/entity/Q1615235',
#  'Burgenlandkreis': 'http://www.wikidata.org/entity/Q14920405',
#  'Böblingen district': 'http://www.wikidata.org/entity/Q8536',
#  'Börde': 'http://www.wikidata.org/entity/Q6064',
#  'Bördekreis': 'http://www.wikidata.org/entity/Q836670',
#  'Büdingen District': 'http://www.wikidata.org/entity/Q1688400',
#  'Bühl (Germany : Landkreis)': 'http://www.wikidata.org/entity/Q1542918',
#  'Bünde District': 'http://www.wikidata.org/entity/Q1378663',
#  'Büren District': 'http://www.wikidata.org/entity/Q1787246',
#  'Calw District': 'http://www.wikidata.org/entity/Q8186',
#  'Celle': 'http://www.wikidata.org/entity/Q5919',
#  'Cham': 'http://www.wikidata.org/entity/Q10424',
#  'Chemnitz': 'http://www.wikidata.org/entity/Q1803113',
#  'Chemnitzer Land': 'http://www.wikidata.org/entity/Q20227',
#  'Cloppenburg': 'http://www.wikidata.org/entity/Q5945',
#  'Coburg': 'http://www.wikidata.org/entity/Q10440',
#  'Cochem-Zell': 'http://www.wikidata.org/entity/Q8590',
#  'Coesfeld': 'http://www.wikidata.org/entity/Q6210',
#  'County of Bentheim': 'http://www.wikidata.org/entity/Q5939',
#  'Cuxhaven': 'http://www.wikidata.org/entity/Q5897',
#  'Dachau': 'http://www.wikidata.org/entity/Q10500',
#  'Dahme-Spreewald District': 'http://www.wikidata.org/entity/Q6173',
#  'Darmstadt-Dieburg': 'http://www.wikidata.org/entity/Q7916',
#  'Deggendorf': 'http://www.wikidata.org/entity/Q10485',
#  'Delitzsch': 'http://www.wikidata.org/entity/Q20230',
#  'Demmin': 'http://www.wikidata.org/entity/Q559530',
#  'Detmold District': 'http://www.wikidata.org/entity/Q1587845',
#  'Dieburg': 'http://www.wikidata.org/entity/Q1803125',
#  'Diepholz': 'http://www.wikidata.org/entity/Q5956',
#  'Diepholz county': 'http://www.wikidata.org/entity/Q1360467',
#  'Dillingen': 'http://www.wikidata.org/entity/Q10417',
#  'Dillkreis': 'http://www.wikidata.org/entity/Q1225581',
#  'Dingolfing-Landau': 'http://www.wikidata.org/entity/Q10480',
#  'District of Erding': 'http://www.wikidata.org/entity/Q10539',
#  'Dithmarschen': 'http://www.wikidata.org/entity/Q2947',
#  'Donau-Ries': 'http://www.wikidata.org/entity/Q10418',
#  'Donauwörth (Germany : Landkreis)': 'http://www.wikidata.org/entity/Q1207655',
#  'Donnersbergkreis': 'http://www.wikidata.org/entity/Q8564',
#  'Dresden (Germany : Landkreis)': 'http://www.wikidata.org/entity/Q15605856',
#  'Duderstadt': 'http://www.wikidata.org/entity/Q1479133',
#  'Döbeln': 'http://www.wikidata.org/entity/Q20233',
#  'Düren': 'http://www.wikidata.org/entity/Q6275',
#  'Ebersberg': 'http://www.wikidata.org/entity/Q10541',
#  'Eggenfelden District': 'http://www.wikidata.org/entity/Q1803137',
#  'Ehingen (Alb-Donau-Kreis, Germany)': 'http://www.wikidata.org/entity/Q1803138',
#  'Eichsfeld': 'http://www.wikidata.org/entity/Q7861',
#  'Eichstätt': 'http://www.wikidata.org/entity/Q10491',
#  'Eifelkreis Bitburg-Prüm': 'http://www.wikidata.org/entity/Q8580',
#  'Elbe-Elster District': 'http://www.wikidata.org/entity/Q6152',
#  'Emmendingen': 'http://www.wikidata.org/entity/Q8193',
#  'Emsland': 'http://www.wikidata.org/entity/Q5936',
#  'Ennepe-Ruhr-Kreis': 'http://www.wikidata.org/entity/Q11280',
#  'Enz': 'http://www.wikidata.org/entity/Q8184',
#  'Erlangen': 'http://www.wikidata.org/entity/Q1320758',
#  'Erlangen-Höchstadt': 'http://www.wikidata.org/entity/Q10447',
#  'Erzgebirgskreis': 'http://www.wikidata.org/entity/Q6339',
#  'Eschwege district': 'http://www.wikidata.org/entity/Q1803150',
#  'Esslingen': 'http://www.wikidata.org/entity/Q8533',
#  'Euskirchen': 'http://www.wikidata.org/entity/Q6280',
#  'Forchheim': 'http://www.wikidata.org/entity/Q10445',
#  'Freiberg': 'http://www.wikidata.org/entity/Q20236',
#  'Freising': 'http://www.wikidata.org/entity/Q10497',
#  'Freudenstadt': 'http://www.wikidata.org/entity/Q8189',
#  'Freyung-Grafenau': 'http://www.wikidata.org/entity/Q10487',
#  'Friesland': 'http://www.wikidata.org/entity/Q5932',
#  'Fulda': 'http://www.wikidata.org/entity/Q7899',
#  'Fürstenfeldbruck': 'http://www.wikidata.org/entity/Q10502',
#  'Fürth': 'http://www.wikidata.org/entity/Q10455',
#  'Gandersheim (Germany : Kreis)': 'http://www.wikidata.org/entity/Q1270682',
#  'Garmisch-Partenkirchen': 'http://www.wikidata.org/entity/Q10518',
#  'Geilenkirchen-Heinsberg': 'http://www.wikidata.org/entity/Q2268218',
#  'Geldern': 'http://www.wikidata.org/entity/Q1673662',
#  'Gemünden am Main': 'http://www.wikidata.org/entity/Q1803174',
#  'Germersheim': 'http://www.wikidata.org/entity/Q8543',
#  'Gießen': 'http://www.wikidata.org/entity/Q7904',
#  'Gifhorn': 'http://www.wikidata.org/entity/Q6053',
#  'Goslar': 'http://www.wikidata.org/entity/Q6040',
#  'Gotha': 'http://www.wikidata.org/entity/Q7869',
#  'Greiz': 'http://www.wikidata.org/entity/Q7887',
#  'Grevenbroich District': 'http://www.wikidata.org/entity/Q1787307',
#  'Groß-Gerau': 'http://www.wikidata.org/entity/Q7914',
#  'Göppingen': 'http://www.wikidata.org/entity/Q8525',
#  'Görlitz': 'http://www.wikidata.org/entity/Q6317',
#  'Göttingen district': 'http://www.wikidata.org/entity/Q6022',
#  'Günzburg': 'http://www.wikidata.org/entity/Q10412',
#  'Güstrow': 'http://www.wikidata.org/entity/Q559600',
#  'Gütersloh': 'http://www.wikidata.org/entity/Q6218',
#  'Halberstadt': 'http://www.wikidata.org/entity/Q114247',
#  'Halle District': 'http://www.wikidata.org/entity/Q166787',
#  'Hamelin-Pyrmont': 'http://www.wikidata.org/entity/Q5970',
#  'Hannover': 'http://www.wikidata.org/entity/Q895926',
#  'Hanover region': 'http://www.wikidata.org/entity/Q5963',
#  'Harburg': 'http://www.wikidata.org/entity/Q5907',
#  'Harz District': 'http://www.wikidata.org/entity/Q6087',
#  'Havelland District': 'http://www.wikidata.org/entity/Q6139',
#  'Haßberge': 'http://www.wikidata.org/entity/Q10462',
#  'Heidekreis': 'http://www.wikidata.org/entity/Q5922',
#  'Heidelberg': 'http://www.wikidata.org/entity/Q1658632',
#  'Heilbronn': 'http://www.wikidata.org/entity/Q7166',
#  'Heinsberg': 'http://www.wikidata.org/entity/Q6264',
#  'Helmstedt district': 'http://www.wikidata.org/entity/Q6047',
#  'Herford': 'http://www.wikidata.org/entity/Q6234',
#  'Hersbruck': 'http://www.wikidata.org/entity/Q1803214',
#  'Hersfeld': 'http://www.wikidata.org/entity/Q1803216',
#  'Hersfeld-Rotenburg': 'http://www.wikidata.org/entity/Q7898',
#  'Herzogtum Lauenburg': 'http://www.wikidata.org/entity/Q3000',
#  'Hildesheim': 'http://www.wikidata.org/entity/Q5978',
#  'Hochsauerlandkreis': 'http://www.wikidata.org/entity/Q5946',
#  'Hochtaunuskreis': 'http://www.wikidata.org/entity/Q7908',
#  'Hof': 'http://www.wikidata.org/entity/Q10431',
#  'Hohenlohe': 'http://www.wikidata.org/entity/Q8518',
#  'Holzminden': 'http://www.wikidata.org/entity/Q5973',
#  'Höxter': 'http://www.wikidata.org/entity/Q6228',
#  'Höxter District': 'http://www.wikidata.org/entity/Q1351319',
#  'Ilm-Kreis': 'http://www.wikidata.org/entity/Q7878',
#  'Ingolstadt': 'http://www.wikidata.org/entity/Q1409438',
#  'Iserlohn District': 'http://www.wikidata.org/entity/Q1322719',
#  'Jerichower Land': 'http://www.wikidata.org/entity/Q6068',
#  'Kamenz': 'http://www.wikidata.org/entity/Q20239',
#  'Karlsruhe': 'http://www.wikidata.org/entity/Q8178',
#  'Karlstadt': 'http://www.wikidata.org/entity/Q1803255',
#  'Kelheim': 'http://www.wikidata.org/entity/Q10474',
#  'Kempen-Krefeld': 'http://www.wikidata.org/entity/Q1787361',
#  'Kitzingen': 'http://www.wikidata.org/entity/Q10459',
#  'Kleve': 'http://www.wikidata.org/entity/Q6246',
#  'Konstanz': 'http://www.wikidata.org/entity/Q8206',
#  'Kreis Bergheim': 'http://www.wikidata.org/entity/Q1644645',
#  'Kreis Bergstraße': 'http://www.wikidata.org/entity/Q7917',
#  'Kreis Dinslaken': 'http://www.wikidata.org/entity/Q1461305',
#  'Kreis Erkelenz': 'http://www.wikidata.org/entity/Q1787280',
#  'Kreis Jülich': 'http://www.wikidata.org/entity/Q1521339',
#  'Kreis Leipzig-Land': 'http://www.wikidata.org/entity/Q1323208',
#  'Kreis Paderborn (1816-1974)': 'http://www.wikidata.org/entity/Q1787449',
#  'Kronach': 'http://www.wikidata.org/entity/Q10434',
#  'Kulmbach': 'http://www.wikidata.org/entity/Q10436',
#  'Kusel': 'http://www.wikidata.org/entity/Q8562',
#  'Kyffhäuserkreis': 'http://www.wikidata.org/entity/Q7862',
#  'Köthen': 'http://www.wikidata.org/entity/Q114216',
#  'Lahn-Dill-Kreis': 'http://www.wikidata.org/entity/Q7905',
#  'Land Hadeln': 'http://www.wikidata.org/entity/Q1790558',
#  'Landkreis Einbeck': 'http://www.wikidata.org/entity/Q1769956',
#  'Landkreis Friedberg': 'http://www.wikidata.org/entity/Q1394948',
#  'Landkreis Hanau': 'http://www.wikidata.org/entity/Q1803209',
#  'Landkreis Heidenheim': 'http://www.wikidata.org/entity/Q8523',
#  'Landkreis Hildburghausen': 'http://www.wikidata.org/entity/Q7872',
#  'Landkreis Illertissen': 'http://www.wikidata.org/entity/Q1803244',
#  'Landkreis Kaiserslautern': 'http://www.wikidata.org/entity/Q8559',
#  'Landkreis Kassel': 'http://www.wikidata.org/entity/Q7890',
#  'Landkreis Krumbach, Swabia': 'http://www.wikidata.org/entity/Q882176',
#  'Landkreis Köln': 'http://www.wikidata.org/entity/Q1803277',
#  'Landkreis Leipzig': 'http://www.wikidata.org/entity/Q6308',
#  'Landkreis Meiningen': 'http://www.wikidata.org/entity/Q1417874',
#  'Landkreis Mergentheim': 'http://www.wikidata.org/entity/Q1803332',
#  'Landkreis Münden': 'http://www.wikidata.org/entity/Q1305418',
#  'Landkreis Naila': 'http://www.wikidata.org/entity/Q1637232',
#  'Landkreis Neustadt am Rübenberge': 'http://www.wikidata.org/entity/Q1803356',
#  'Landkreis Nienburg/Weser': 'http://www.wikidata.org/entity/Q5958',
#  'Landkreis Nürtingen': 'http://www.wikidata.org/entity/Q1345395',
#  'Landkreis Ravensburg': 'http://www.wikidata.org/entity/Q8225',
#  'Landkreis Rotenburg': 'http://www.wikidata.org/entity/Q1803417',
#  'Landkreis Saalfeld-Rudolstadt': 'http://www.wikidata.org/entity/Q7882',
#  'Landkreis Schwäbisch Hall': 'http://www.wikidata.org/entity/Q8520',
#  'Landkreis Sigmaringen': 'http://www.wikidata.org/entity/Q8230',
#  'Landkreis Sonthofen': 'http://www.wikidata.org/entity/Q1803468',
#  'Landkreis Tauberbischofsheim': 'http://www.wikidata.org/entity/Q1397320',
#  'Landkreis Trier': 'http://www.wikidata.org/entity/Q1803508',
#  'Landkreis Weilheim in Upper Bavaria': 'http://www.wikidata.org/entity/Q1388621',
#  'Landkreis Zell': 'http://www.wikidata.org/entity/Q1803579',
#  'Landsberg am Lech': 'http://www.wikidata.org/entity/Q10507',
#  'Landshut': 'http://www.wikidata.org/entity/Q10475',
#  'Lauterbach (Germany : Kreis)': 'http://www.wikidata.org/entity/Q652979',
#  'Leer': 'http://www.wikidata.org/entity/Q5934',
#  'Leipziger Land': 'http://www.wikidata.org/entity/Q20242',
#  'Lemgo District': 'http://www.wikidata.org/entity/Q1543152',
#  'Lichtenfels': 'http://www.wikidata.org/entity/Q10442',
#  'Limburg-Weilburg': 'http://www.wikidata.org/entity/Q7906',
#  'Lindau': 'http://www.wikidata.org/entity/Q10401',
#  'Lingen': 'http://www.wikidata.org/entity/Q1803305',
#  'Lippe': 'http://www.wikidata.org/entity/Q6230',
#  'Lippstadt District': 'http://www.wikidata.org/entity/Q1787383',
#  'Lohr': 'http://www.wikidata.org/entity/Q1803308',
#  'Ludwigsburg': 'http://www.wikidata.org/entity/Q8541',
#  'Ludwigslust': 'http://www.wikidata.org/entity/Q385635',
#  'Ludwigslust-Parchim District': 'http://www.wikidata.org/entity/Q2905',
#  'Löbau-Zittau': 'http://www.wikidata.org/entity/Q20245',
#  'Lörrach': 'http://www.wikidata.org/entity/Q8198',
#  'Lübbecke District': 'http://www.wikidata.org/entity/Q1739523',
#  'Lüchow-Dannenberg District': 'http://www.wikidata.org/entity/Q5913',
#  'Lüdenscheid District': 'http://www.wikidata.org/entity/Q1738986',
#  'Lüdinghausen District': 'http://www.wikidata.org/entity/Q895515',
#  'Lüneburg': 'http://www.wikidata.org/entity/Q5910',
#  'Main-Kinzig-Kreis': 'http://www.wikidata.org/entity/Q7911',
#  'Main-Spessart': 'http://www.wikidata.org/entity/Q10469',
#  'Main-Tauber-Kreis': 'http://www.wikidata.org/entity/Q8517',
#  'Main-Taunus-Kreis': 'http://www.wikidata.org/entity/Q7909',
#  'Mainz-Bingen': 'http://www.wikidata.org/entity/Q8569',
#  'Mallersdorf district': 'http://www.wikidata.org/entity/Q1803316',
#  'Mannheim': 'http://www.wikidata.org/entity/Q1803318',
#  'Mansfeld-Südharz': 'http://www.wikidata.org/entity/Q6092',
#  'Mansfelder Land': 'http://www.wikidata.org/entity/Q113961',
#  'Marburg (Germany : Landkreis)': 'http://www.wikidata.org/entity/Q1527963',
#  'Marburg-Biedenkopf': 'http://www.wikidata.org/entity/Q7902',
#  'Marktheidenfeld': 'http://www.wikidata.org/entity/Q1803322',
#  'Mayen': 'http://www.wikidata.org/entity/Q1803325',
#  'Mayen-Koblenz': 'http://www.wikidata.org/entity/Q8593',
#  'Mecklenburg-Strelitz': 'http://www.wikidata.org/entity/Q559552',
#  'Mecklenburgische Seenplatte District': 'http://www.wikidata.org/entity/Q2902',
#  'Meissen District': 'http://www.wikidata.org/entity/Q6313',
#  'Meißen': 'http://www.wikidata.org/entity/Q20248',
#  'Melle': 'http://www.wikidata.org/entity/Q1689254',
#  'Mellrichstadt': 'http://www.wikidata.org/entity/Q1147681',
#  'Melsungen': 'http://www.wikidata.org/entity/Q1803329',
#  'Merseburg-Querfurt': 'http://www.wikidata.org/entity/Q115352',
#  'Merzig-Wadern': 'http://www.wikidata.org/entity/Q6802',
#  'Meschede District': 'http://www.wikidata.org/entity/Q1747717',
#  'Mettmann': 'http://www.wikidata.org/entity/Q6257',
#  'Miesbach': 'http://www.wikidata.org/entity/Q10523',
#  'Miltenberg': 'http://www.wikidata.org/entity/Q10472',
#  'Mindelheim': 'http://www.wikidata.org/entity/Q1664009',
#  'Minden District': 'http://www.wikidata.org/entity/Q1412180',
#  'Minden-Lübbecke District': 'http://www.wikidata.org/entity/Q6239',
#  'Mittelsachsen': 'http://www.wikidata.org/entity/Q6328',
#  'Mittlerer Erzgebirgskreis': 'http://www.wikidata.org/entity/Q20250',
#  'Mittweida': 'http://www.wikidata.org/entity/Q20253',
#  'Muldentalkreis': 'http://www.wikidata.org/entity/Q20256',
#  'Munich': 'http://www.wikidata.org/entity/Q10544',
#  'Märkisch-Oderland District': 'http://www.wikidata.org/entity/Q6181',
#  'Märkischer Kreis': 'http://www.wikidata.org/entity/Q5937',
#  'Mühldorf': 'http://www.wikidata.org/entity/Q10537',
#  'Münster District': 'http://www.wikidata.org/entity/Q878752',
#  'Müritz': 'http://www.wikidata.org/entity/Q164955',
#  'Neckar-Odenwald': 'http://www.wikidata.org/entity/Q8174',
#  'Neu-Ulm': 'http://www.wikidata.org/entity/Q10410',
#  'Neuburg-Schrobenhausen': 'http://www.wikidata.org/entity/Q10493',
#  'Neumarkt': 'http://www.wikidata.org/entity/Q10427',
#  'Neunkirchen': 'http://www.wikidata.org/entity/Q6799',
#  'Neustadt (Aisch)-Bad Windsheim': 'http://www.wikidata.org/entity/Q10456',
#  'Neustadt an der Waldnaab': 'http://www.wikidata.org/entity/Q10420',
#  'Neuwied': 'http://www.wikidata.org/entity/Q8606',
#  'Niederschlesischer Oberlausitzkreis': 'http://www.wikidata.org/entity/Q20259',
#  'Nordfriesland district': 'http://www.wikidata.org/entity/Q2937',
#  'Nordhausen': 'http://www.wikidata.org/entity/Q7858',
#  'Nordsachsen': 'http://www.wikidata.org/entity/Q6301',
#  'Nordvorpommern': 'http://www.wikidata.org/entity/Q559510',
#  'Nordwestmecklenburg District': 'http://www.wikidata.org/entity/Q2876',
#  'Northeim': 'http://www.wikidata.org/entity/Q6018',
#  'Nürnberger Land': 'http://www.wikidata.org/entity/Q10449',
#  'Oberallgäu': 'http://www.wikidata.org/entity/Q10402',
#  'Oberbergischer Kreis': 'http://www.wikidata.org/entity/Q6298',
#  'Oberhavel District': 'http://www.wikidata.org/entity/Q6119',
#  'Oberspreewald-Lausitz District': 'http://www.wikidata.org/entity/Q6156',
#  'Odenwaldkreis': 'http://www.wikidata.org/entity/Q7919',
#  'Oder-Spree District': 'http://www.wikidata.org/entity/Q6178',
#  'Offenbach': 'http://www.wikidata.org/entity/Q7912',
#  'Ohrekreis': 'http://www.wikidata.org/entity/Q696771',
#  'Oldenburg': 'http://www.wikidata.org/entity/Q5952',
#  'Olpe': 'http://www.wikidata.org/entity/Q5953',
#  'Ortenau': 'http://www.wikidata.org/entity/Q8191',
#  'Osnabrück': 'http://www.wikidata.org/entity/Q5940',
#  'Ostalbkreis': 'http://www.wikidata.org/entity/Q8522',
#  'Ostallgäu': 'http://www.wikidata.org/entity/Q10405',
#  'Osterholz': 'http://www.wikidata.org/entity/Q5926',
#  'Osterode': 'http://www.wikidata.org/entity/Q6037',
#  'Ostholstein': 'http://www.wikidata.org/entity/Q2975',
#  'Ostprignitz-Ruppin District': 'http://www.wikidata.org/entity/Q6125',
#  'Ostvorpommern': 'http://www.wikidata.org/entity/Q559583',
#  'Paderborn': 'http://www.wikidata.org/entity/Q6224',
#  'Parchim': 'http://www.wikidata.org/entity/Q430923',
#  'Passau': 'http://www.wikidata.org/entity/Q10489',
#  'Pegnitz': 'http://www.wikidata.org/entity/Q1445349',
#  'Peine': 'http://www.wikidata.org/entity/Q6045',
#  'Pfaffenhofen a. d. Ilm': 'http://www.wikidata.org/entity/Q10496',
#  'Pinneberg': 'http://www.wikidata.org/entity/Q3006',
#  'Pirna': 'http://www.wikidata.org/entity/Q1699727',
#  'Plön District': 'http://www.wikidata.org/entity/Q2970',
#  'Potsdam-Mittelmark District': 'http://www.wikidata.org/entity/Q6142',
#  'Prignitz District': 'http://www.wikidata.org/entity/Q6132',
#  'Prüm': 'http://www.wikidata.org/entity/Q1803394',
#  'Quedlinburg': 'http://www.wikidata.org/entity/Q114539',
#  'Rahden District': 'http://www.wikidata.org/entity/Q56881361',
#  'Rastatt': 'http://www.wikidata.org/entity/Q8182',
#  'Recklinghausen': 'http://www.wikidata.org/entity/Q6214',
#  'Rees District': 'http://www.wikidata.org/entity/Q1759911',
#  'Regen district': 'http://www.wikidata.org/entity/Q10483',
#  'Regensburg': 'http://www.wikidata.org/entity/Q10429',
#  'Regionalverband Saarbrücken': 'http://www.wikidata.org/entity/Q6805',
#  'Rems-Murr': 'http://www.wikidata.org/entity/Q8528',
#  'Rendsburg-Eckernförde': 'http://www.wikidata.org/entity/Q2967',
#  'Reutlingen': 'http://www.wikidata.org/entity/Q8217',
#  'Rhein-Berg District': 'http://www.wikidata.org/entity/Q6295',
#  'Rhein-Erft District': 'http://www.wikidata.org/entity/Q6292',
#  'Rhein-Hunsrück-Kreis': 'http://www.wikidata.org/entity/Q8574',
#  'Rhein-Kreis Neuss': 'http://www.wikidata.org/entity/Q6253',
#  'Rhein-Lahn-Kreis': 'http://www.wikidata.org/entity/Q8601',
#  'Rhein-Neckar': 'http://www.wikidata.org/entity/Q8177',
#  'Rhein-Pfalz-Kreis': 'http://www.wikidata.org/entity/Q8554',
#  'Rhein-Sieg District': 'http://www.wikidata.org/entity/Q6287',
#  'Rhein-Wupper-Kreis': 'http://www.wikidata.org/entity/Q2147516',
#  'Rheingau-Taunus-Kreis': 'http://www.wikidata.org/entity/Q7907',
#  'Rhön-Grabfeld': 'http://www.wikidata.org/entity/Q10465',
#  'Riesa-Großenhain': 'http://www.wikidata.org/entity/Q20262',
#  'Rosenheim': 'http://www.wikidata.org/entity/Q10526',
#  'Rostock District': 'http://www.wikidata.org/entity/Q2898',
#  'Rotenburg (Wümme)': 'http://www.wikidata.org/entity/Q5923',
#  'Rotenburg (Wümme) county': 'http://www.wikidata.org/entity/Q1803420',
#  'Roth': 'http://www.wikidata.org/entity/Q10451',
#  'Rottal-Inn': 'http://www.wikidata.org/entity/Q10477',
#  'Rottweil': 'http://www.wikidata.org/entity/Q8211',
#  'Rügen': 'http://www.wikidata.org/entity/Q164867',
#  'Saale-Holzland-Kreis': 'http://www.wikidata.org/entity/Q7884',
#  'Saale-Orla-Kreis': 'http://www.wikidata.org/entity/Q7883',
#  'Saalekreis': 'http://www.wikidata.org/entity/Q6098',
#  'Saalkreis': 'http://www.wikidata.org/entity/Q702558',
#  'Saarlouis': 'http://www.wikidata.org/entity/Q6794',
#  'Saarpfalz-Kreis': 'http://www.wikidata.org/entity/Q6793',
#  'Salzlandkreis': 'http://www.wikidata.org/entity/Q6081',
#  'Sangerhausen': 'http://www.wikidata.org/entity/Q81415',
#  'Schaumburg': 'http://www.wikidata.org/entity/Q5966',
#  'Schleiden': 'http://www.wikidata.org/entity/Q1366459',
#  'Schleswig-Flensburg': 'http://www.wikidata.org/entity/Q2941',
#  'Schmalkalden-Meiningen': 'http://www.wikidata.org/entity/Q7871',
#  'Schwabach': 'http://www.wikidata.org/entity/Q1207546',
#  'Schwabmünchen': 'http://www.wikidata.org/entity/Q1803450',
#  'Schwalm-Eder-Kreis': 'http://www.wikidata.org/entity/Q7894',
#  'Schwandorf': 'http://www.wikidata.org/entity/Q10423',
#  'Schwarzwald-Baar district': 'http://www.wikidata.org/entity/Q8203',
#  'Schweinfurt': 'http://www.wikidata.org/entity/Q10461',
#  'Schönebeck': 'http://www.wikidata.org/entity/Q114625',
#  'Sebnitz': 'http://www.wikidata.org/entity/Q15101291',
#  'Segeberg': 'http://www.wikidata.org/entity/Q2980',
#  'Siegen District': 'http://www.wikidata.org/entity/Q1787514',
#  'Siegen-Wittgenstein': 'http://www.wikidata.org/entity/Q5982',
#  'Siegkreis': 'http://www.wikidata.org/entity/Q1372871',
#  'Simmern': 'http://www.wikidata.org/entity/Q1803460',
#  'Sinsheim': 'http://www.wikidata.org/entity/Q1803462',
#  'Soest': 'http://www.wikidata.org/entity/Q5965',
#  'Soest District': 'http://www.wikidata.org/entity/Q1113210',
#  'Soltau': 'http://www.wikidata.org/entity/Q1803466',
#  'Sonneberg': 'http://www.wikidata.org/entity/Q7875',
#  'Spree-Neiße District': 'http://www.wikidata.org/entity/Q6165',
#  'St. Wendel': 'http://www.wikidata.org/entity/Q6789',
#  'Stade': 'http://www.wikidata.org/entity/Q5906',
#  'Starnberg': 'http://www.wikidata.org/entity/Q10504',
#  'Steinburg': 'http://www.wikidata.org/entity/Q3011',
#  'Steinfurt': 'http://www.wikidata.org/entity/Q6187',
#  'Stendal District': 'http://www.wikidata.org/entity/Q6057',
#  'Stockach': 'http://www.wikidata.org/entity/Q1803482',
#  'Stollberg': 'http://www.wikidata.org/entity/Q20266',
#  'Stormarn': 'http://www.wikidata.org/entity/Q3003',
#  'Straubing-Bogen': 'http://www.wikidata.org/entity/Q10482',
#  'Sächsische Schweiz': 'http://www.wikidata.org/entity/Q20264',
#  'Sächsische Schweiz-Osterzgebirge': 'http://www.wikidata.org/entity/Q6323',
#  'Sömmerda': 'http://www.wikidata.org/entity/Q7865',
#  'Südliche Weinstraße': 'http://www.wikidata.org/entity/Q8551',
#  'Südwestpfalz': 'http://www.wikidata.org/entity/Q8552',
#  'Tecklenburg District': 'http://www.wikidata.org/entity/Q897140',
#  'Teltow-Fläming District': 'http://www.wikidata.org/entity/Q6146',
#  'Tirschenreuth': 'http://www.wikidata.org/entity/Q10419',
#  'Torgau-Oschatz': 'http://www.wikidata.org/entity/Q20269',
#  'Traunstein': 'http://www.wikidata.org/entity/Q10528',
#  'Trier-Saarburg': 'http://www.wikidata.org/entity/Q8579',
#  'Tuttlingen': 'http://www.wikidata.org/entity/Q8208',
#  'Tübingen': 'http://www.wikidata.org/entity/Q8214',
#  'Uckermark District': 'http://www.wikidata.org/entity/Q6109',
#  'Uecker-Randow': 'http://www.wikidata.org/entity/Q559492',
#  'Uelzen District': 'http://www.wikidata.org/entity/Q5915',
#  'Uffenheim': 'http://www.wikidata.org/entity/Q1803514',
#  'Unna': 'http://www.wikidata.org/entity/Q6163',
#  'Unstrut-Hainich-Kreis': 'http://www.wikidata.org/entity/Q7864',
#  'Unterallgäu': 'http://www.wikidata.org/entity/Q10408',
#  'Untertaunuskreis': 'http://www.wikidata.org/entity/Q1494387',
#  'Vechta': 'http://www.wikidata.org/entity/Q5941',
#  'Verden': 'http://www.wikidata.org/entity/Q5927',
#  'Viersen': 'http://www.wikidata.org/entity/Q6249',
#  'Vogelsbergkreis': 'http://www.wikidata.org/entity/Q7901',
#  'Vogtlandkreis': 'http://www.wikidata.org/entity/Q6337',
#  'Vohenstrauss': 'http://www.wikidata.org/entity/Q1803519',
#  'Vorpommern-Greifswald District': 'http://www.wikidata.org/entity/Q2917',
#  'Vorpommern-Rügen District': 'http://www.wikidata.org/entity/Q2909',
#  'Vulkaneifel': 'http://www.wikidata.org/entity/Q8583',
#  'Waiblingen': 'http://www.wikidata.org/entity/Q1803521',
#  'Waldeck-Frankenberg': 'http://www.wikidata.org/entity/Q7893',
#  'Waldshut': 'http://www.wikidata.org/entity/Q8200',
#  'Warburg District': 'http://www.wikidata.org/entity/Q1787563',
#  'Warendorf District': 'http://www.wikidata.org/entity/Q16332967',
#  'Wartburgkreis': 'http://www.wikidata.org/entity/Q7866',
#  'Wasserburg am Inn': 'http://www.wikidata.org/entity/Q1803535',
#  'Weilheim-Schongau': 'http://www.wikidata.org/entity/Q10516',
#  'Weimarer Land': 'http://www.wikidata.org/entity/Q7879',
#  'Weißenburg-Gunzenhausen': 'http://www.wikidata.org/entity/Q10453',
#  'Weißenfels District': 'http://www.wikidata.org/entity/Q114207',
#  'Weißeritzkreis': 'http://www.wikidata.org/entity/Q20274',
#  'Werra-Meißner-Kreis': 'http://www.wikidata.org/entity/Q7896',
#  'Wertingen': 'http://www.wikidata.org/entity/Q1668435',
#  'Wesel': 'http://www.wikidata.org/entity/Q6245',
#  'Wesermarsch': 'http://www.wikidata.org/entity/Q5948',
#  'Westerwaldkreis': 'http://www.wikidata.org/entity/Q8602',
#  'Wetteraukreis': 'http://www.wikidata.org/entity/Q7910',
#  'Wiedenbrück District': 'http://www.wikidata.org/entity/Q180248',
#  'Wittenberg': 'http://www.wikidata.org/entity/Q6075',
#  'Wittgenstein District': 'http://www.wikidata.org/entity/Q1787578',
#  'Wittlage': 'http://www.wikidata.org/entity/Q1803554',
#  'Wittlich': 'http://www.wikidata.org/entity/Q1712835',
#  'Wittmund': 'http://www.wikidata.org/entity/Q5931',
#  'Wolfenbüttel': 'http://www.wikidata.org/entity/Q6041',
#  'Wolfratshausen': 'http://www.wikidata.org/entity/Q1803560',
#  'Worms': 'http://www.wikidata.org/entity/Q1803563',
#  'Wunsiedel': 'http://www.wikidata.org/entity/Q10432',
#  'Würzburg': 'http://www.wikidata.org/entity/Q10458',
#  'Zellerfeld District': 'http://www.wikidata.org/entity/Q1613939',
#  'Zollernalb': 'http://www.wikidata.org/entity/Q8233',
#  'Zwickau': 'http://www.wikidata.org/entity/Q6330',
#  'Zwickauer Land': 'http://www.wikidata.org/entity/Q20271',
#  'district of Wernigerode': 'http://www.wikidata.org/entity/Q114127'}
# number of found places: 480

# %% [markdown]
# ## Generate questions

# %%
import time
import random
random.seed(round(time.time() * 1000))

def get_random_parameters(parameters):
    result = {}
    for k in parameters.keys():
        if not k in ["PLACE_URL","DISTRICT_URL","DISTRICT_LABEL"]: # TODO: needs to be generalized
            random_key = random.randint(0,len(parameters[k])-1)
            try:
                result[k] = parameters[k][random_key]
            except Exception as e:
                print(f"random_key: {random_key}")
                pprint(parameters[k])
                raise e
        else:
            pass # skip should only happen in case of dependent values

    # find the concrete district for the given place
    result["PLACE_URL"] = parameters["PLACE_URL"][result["PLACE_LABEL"]] # TODO: needs to be generalized
    result["DISTRICT_URL"] = parameters["DISTRICT_URL"][result["PLACE_URL"]] # TODO: needs to be generalized
    result["DISTRICT_LABEL"] = parameters["DISTRICT_LABEL"][result["PLACE_URL"]] # TODO: needs to be generalized

    return result

def get_random_list_of_templates_questions(questions, number_of_questions_to_be_selected):
    randomly_selected_questions = []
    number_of_available_questions = len(questions)
    for i in range(number_of_questions_to_be_selected):
        random_key = random.randint(0,number_of_available_questions-1)
        randomly_selected_questions.append(questions[random_key])
    return randomly_selected_questions

generated_questions = []

random_templates = get_random_list_of_templates_questions(templates, max_number_of_used_templates)
for template in random_templates:
    questions = template["questions"]
    for question in questions:
        concrete_parameters = get_random_parameters(parameters)
        for place_holder, concrete_instance in concrete_parameters.items():
            question = question.replace('['+place_holder+']', str(concrete_instance))

        concrete_parameters_merged = {}
        if template.get("parameters", None) != None: # there might be predefined parameters of the question template
            concrete_parameters_merged = {**template.get("parameters"), **concrete_parameters}
        else:
            concrete_parameters_merged = concrete_parameters
        generated_question_configuration = {"question": question, "replacements": concrete_parameters_merged, "template": template}

        generated_questions.append(generated_question_configuration)

if len(generated_questions) > max_number_of_generated_questions:
    random.shuffle(generated_questions) # compute random order
    generated_questions = generated_questions[:max_number_of_generated_questions] # reduce number of questions

pprint(generated_questions, width=120)

generated_configuration = {}
generated_configuration["qanary"] = {
    "system_url": "https://webengineering.ins.hs-anhalt.de:43740/startquestionansweringwithtextquestion",
    # "componentlist": ["LD-Shuyo", "coronabot-dialog-flow", "coronabot-question-classification", "coronabot-named-entity-recognition-time-en", "coronabot-named-entity-recognition-time-de", "coronabot-named-entity-recognition-location-en", "coronabot-named-entity-recognition-location-de", "OpenTapiocaNED", "LocationToGermanDistrict", "coronabot-missing-information", "coronabot-query-generation", "coronabot-data-acquisition", "coronabot-answer-generation"],
    "componentlist": ["LD-Shuyo", "coronabot-dialog-flow", "coronabot-question-classification", "coronabot-named-entity-recognition-time-en", "coronabot-named-entity-recognition-location-en", "OpenTapiocaNED", "LocationToGermanDistrict", "coronabot-missing-information", "coronabot-query-generation", "coronabot-data-acquisition", "coronabot-answer-generation"],
    "qanary_triplestore_endpoint": "https://webengineering.ins.hs-anhalt.de:40159",
    "qanary_triplestore_database": "qanary",
    "qanary_triplestore_username": "admin",
    "qanary_triplestore_password": "admin"
}
generated_configuration["tests"] = generated_questions
generated_configuration["validation-sparql-templates"] = ["01_language_detection.sparql","02_question_classification.sparql", "03_time_recognition.sparql", "04_ned.sparql", "05_location_to_german_district.sparql", "06_coronabot_missing_information.sparql", "07_rki_query.sparql"]
# generated_configuration["custom-validation"] = "dummy" # should not be defined if not required

pprint(generated_configuration, width=120)

print("number of questions: ", len(generated_questions))
# Out:
# [{'question': 'infections between the first and 28th of last March?',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Kelheim',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q10474',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'March',
#                    'PLACE_LABEL': 'Kelheim',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q10474',
#                    'QUESTION_CLASS': 'infection_time',
#                    'YEAR': 2021},
#   'template': {'last': True,
#                'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'infection_time'},
#                'questions': ['How many cases were reported on the first of last [MONTH]?',
#                              'What was the number of infections last [MONTH]?',
#                              'infections between the first and 28th of last [MONTH]?',
#                              'How many people were infected with Covid-19 last [MONTH]',
#                              'corona cases last [MONTH]']}},
#  {'question': 'How many people have been infected in Pirna in total?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': False,
#                    'DISTRICT_LABEL': 'Pirna',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q1699727',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'August',
#                    'PLACE_LABEL': 'Pirna',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q1699727',
#                    'QUESTION_CLASS': 'infection_location',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': False, 'QUESTION_CLASS': 'infection_location'},
#                'questions': ['Infections in [PLACE_LABEL] and Kiel?',
#                              'Cases in [PLACE_LABEL]?',
#                              'How many people have been infected in [PLACE_LABEL] in total?',
#                              '[PLACE_LABEL] corona cases',
#                              'give me the number of infections in [PLACE_LABEL]']}},
#  {'question': 'What was the death toll in Kitzingen during May of 2020?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Kitzingen',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q10459',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'May',
#                    'PLACE_LABEL': 'Kitzingen',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q10459',
#                    'QUESTION_CLASS': 'death_location_time',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_location_time'},
#                'questions': ['What was the death toll in [PLACE_LABEL] during [MONTH] of [YEAR]?',
#                              'How many people died in [PLACE_LABEL] in [MONTH] [YEAR]?',
#                              'How many deaths were reported in [PLACE_LABEL] in [MONTH] [YEAR]?',
#                              'covid deaths in [PLACE_LABEL] in [MONTH] of [YEAR]',
#                              'how many deaths did [PLACE_LABEL] have in [MONTH] [YEAR]?']}},
#  {'question': 'infections between the first and 28th of last September?',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Tübingen',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q8214',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'September',
#                    'PLACE_LABEL': 'Tübingen',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q8214',
#                    'QUESTION_CLASS': 'infection_time',
#                    'YEAR': 2020},
#   'template': {'last': True,
#                'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'infection_time'},
#                'questions': ['How many cases were reported on the first of last [MONTH]?',
#                              'What was the number of infections last [MONTH]?',
#                              'infections between the first and 28th of last [MONTH]?',
#                              'How many people were infected with Covid-19 last [MONTH]',
#                              'corona cases last [MONTH]']}},
#  {'question': 'In 2020, how many people were infected in Ludwigslust-Parchim District?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Ludwigslust-Parchim District',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q2905',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'June',
#                    'PLACE_LABEL': 'Ludwigslust-Parchim District',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q2905',
#                    'QUESTION_CLASS': 'infection_location_time',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True,
#                               'CONTAINS_TIME': True,
#                               'QUESTION_CLASS': 'infection_location_time'},
#                'questions': ['What was the number of incidents of [PLACE_LABEL] in [YEAR]?',
#                              'In [YEAR], how many people were infected in [PLACE_LABEL]?',
#                              'What was the number of infections during [YEAR] in [PLACE_LABEL]?']}},
#  {'question': 'How many cases were reported on the first of January 2021?',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Wertingen',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q1668435',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'January',
#                    'PLACE_LABEL': 'Wertingen',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q1668435',
#                    'QUESTION_CLASS': 'infection_time',
#                    'YEAR': 2021},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'infection_time'},
#                'questions': ['How many cases were reported on the first of [MONTH] [YEAR]?',
#                              'What was the number of infections during [MONTH] [YEAR]?',
#                              'infections between the first of [MONTH] [YEAR] and the 28th of [MONTH] [YEAR]?',
#                              'How many people were infected with Covid-19 in [MONTH] [YEAR]',
#                              'corona cases in [MONTH] [YEAR]']}},
#  {'question': 'How many people were infected with Covid-19 in October 2020',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Pfaffenhofen a. d. Ilm',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q10496',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'October',
#                    'PLACE_LABEL': 'Pfaffenhofen a. d. Ilm',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q10496',
#                    'QUESTION_CLASS': 'infection_time',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'infection_time'},
#                'questions': ['How many cases were reported on the first of [MONTH] [YEAR]?',
#                              'What was the number of infections during [MONTH] [YEAR]?',
#                              'infections between the first of [MONTH] [YEAR] and the 28th of [MONTH] [YEAR]?',
#                              'How many people were infected with Covid-19 in [MONTH] [YEAR]',
#                              'corona cases in [MONTH] [YEAR]']}},
#  {'question': 'What was the death toll last May?',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Rhön-Grabfeld',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q10465',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'May',
#                    'PLACE_LABEL': 'Rhön-Grabfeld',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q10465',
#                    'QUESTION_CLASS': 'death_time',
#                    'YEAR': 2021},
#   'template': {'last': True,
#                'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_time'},
#                'questions': ['How many people died during last [MONTH]?',
#                              'How many deaths were reported in last [MONTH]?',
#                              'covid deaths on the fith of last [MONTH]',
#                              'What was the death toll last [MONTH]?',
#                              'number of deaths from the first until the 15th of last [MONTH]']}},
#  {'question': 'how many deaths did Paderborn have in October 2021?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Paderborn',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q6224',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'October',
#                    'PLACE_LABEL': 'Paderborn',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q6224',
#                    'QUESTION_CLASS': 'death_location_time',
#                    'YEAR': 2021},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_location_time'},
#                'questions': ['What was the death toll in [PLACE_LABEL] during [MONTH] of [YEAR]?',
#                              'How many people died in [PLACE_LABEL] in [MONTH] [YEAR]?',
#                              'How many deaths were reported in [PLACE_LABEL] in [MONTH] [YEAR]?',
#                              'covid deaths in [PLACE_LABEL] in [MONTH] of [YEAR]',
#                              'how many deaths did [PLACE_LABEL] have in [MONTH] [YEAR]?']}},
#  {'question': 'How many people died in Brakel District?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': False,
#                    'DISTRICT_LABEL': 'Brakel District',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q1787232',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'September',
#                    'PLACE_LABEL': 'Brakel District',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q1787232',
#                    'QUESTION_CLASS': 'death_location',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': False, 'QUESTION_CLASS': 'death_location'},
#                'questions': ['How many people died in [PLACE_LABEL]?',
#                              'How many deaths were reported in [PLACE_LABEL]?',
#                              'covid deaths in [PLACE_LABEL]',
#                              'What is the current death toll in [PLACE_LABEL]?']}},
#  {'question': 'corona cases last February',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Torgau-Oschatz',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q20269',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'February',
#                    'PLACE_LABEL': 'Torgau-Oschatz',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q20269',
#                    'QUESTION_CLASS': 'infection_time',
#                    'YEAR': 2021},
#   'template': {'last': True,
#                'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'infection_time'},
#                'questions': ['How many cases were reported on the first of last [MONTH]?',
#                              'What was the number of infections last [MONTH]?',
#                              'infections between the first and 28th of last [MONTH]?',
#                              'How many people were infected with Covid-19 last [MONTH]',
#                              'corona cases last [MONTH]']}},
#  {'question': 'How many people died in Reutlingen in August 2020?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Reutlingen',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q8217',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'August',
#                    'PLACE_LABEL': 'Reutlingen',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q8217',
#                    'QUESTION_CLASS': 'death_location_time',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_location_time'},
#                'questions': ['What was the death toll in [PLACE_LABEL] during [MONTH] of [YEAR]?',
#                              'How many people died in [PLACE_LABEL] in [MONTH] [YEAR]?',
#                              'How many deaths were reported in [PLACE_LABEL] in [MONTH] [YEAR]?',
#                              'covid deaths in [PLACE_LABEL] in [MONTH] of [YEAR]',
#                              'how many deaths did [PLACE_LABEL] have in [MONTH] [YEAR]?']}},
#  {'question': 'How many people died during June 2021?',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Wesermarsch',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q5948',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'June',
#                    'PLACE_LABEL': 'Wesermarsch',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q5948',
#                    'QUESTION_CLASS': 'death_time',
#                    'YEAR': 2021},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_time'},
#                'questions': ['How many people died during [MONTH] [YEAR]?',
#                              'How many deaths were reported in [MONTH] of [YEAR]?',
#                              'covid deaths on the fith of [MONTH] [YEAR]',
#                              'What was the death toll during [MONTH] [YEAR]?',
#                              'number of deaths from first of [MONTH] until 15th of [MONTH] [YEAR]']}},
#  {'question': 'Give me the number of cases in Hochtaunuskreis during October 2020!',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Hochtaunuskreis',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q7908',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'October',
#                    'PLACE_LABEL': 'Hochtaunuskreis',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q7908',
#                    'QUESTION_CLASS': 'infection_location_time',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True,
#                               'CONTAINS_TIME': True,
#                               'QUESTION_CLASS': 'infection_location_time'},
#                'questions': ['How many infections were there in [PLACE_LABEL] in [MONTH] [YEAR]?',
#                              'In [MONTH] [YEAR], how many people were infected in [PLACE_LABEL]?',
#                              'Give me the number of cases in [PLACE_LABEL] during [MONTH] [YEAR]!',
#                              'How many cases of Covid did [PLACE_LABEL] report in [MONTH] [YEAR]?',
#                              'infections in [MONTH] [YEAR] in [PLACE_LABEL]']}},
#  {'question': 'How many people died in Wittlage last September?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Wittlage',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q1803554',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'September',
#                    'PLACE_LABEL': 'Wittlage',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q1803554',
#                    'QUESTION_CLASS': 'death_location_time',
#                    'YEAR': 2020},
#   'template': {'last': True,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_location_time'},
#                'questions': ['What was the death toll in [PLACE_LABEL] during the last [MONTH]?',
#                              'How many people died in [PLACE_LABEL] last [MONTH]?',
#                              'How many deaths were reported last [MONTH] in [PLACE_LABEL]?',
#                              'covid deaths in [PLACE_LABEL] last [MONTH]',
#                              'how many deaths did [PLACE_LABEL] have last [MONTH]?']}},
#  {'question': 'covid deaths in Freudenstadt in October of 2020',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Freudenstadt',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q8189',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'October',
#                    'PLACE_LABEL': 'Freudenstadt',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q8189',
#                    'QUESTION_CLASS': 'death_location_time',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_location_time'},
#                'questions': ['What was the death toll in [PLACE_LABEL] during [MONTH] of [YEAR]?',
#                              'How many people died in [PLACE_LABEL] in [MONTH] [YEAR]?',
#                              'How many deaths were reported in [PLACE_LABEL] in [MONTH] [YEAR]?',
#                              'covid deaths in [PLACE_LABEL] in [MONTH] of [YEAR]',
#                              'how many deaths did [PLACE_LABEL] have in [MONTH] [YEAR]?']}},
#  {'question': 'What was the death toll in Sächsische Schweiz-Osterzgebirge during the last January?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Sächsische Schweiz-Osterzgebirge',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q6323',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'January',
#                    'PLACE_LABEL': 'Sächsische Schweiz-Osterzgebirge',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q6323',
#                    'QUESTION_CLASS': 'death_location_time',
#                    'YEAR': 2021},
#   'template': {'last': True,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_location_time'},
#                'questions': ['What was the death toll in [PLACE_LABEL] during the last [MONTH]?',
#                              'How many people died in [PLACE_LABEL] last [MONTH]?',
#                              'How many deaths were reported last [MONTH] in [PLACE_LABEL]?',
#                              'covid deaths in [PLACE_LABEL] last [MONTH]',
#                              'how many deaths did [PLACE_LABEL] have last [MONTH]?']}},
#  {'question': 'How many people were infected with Covid-19 last January',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Quedlinburg',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q114539',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'January',
#                    'PLACE_LABEL': 'Quedlinburg',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q114539',
#                    'QUESTION_CLASS': 'infection_time',
#                    'YEAR': 2020},
#   'template': {'last': True,
#                'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'infection_time'},
#                'questions': ['How many cases were reported on the first of last [MONTH]?',
#                              'What was the number of infections last [MONTH]?',
#                              'infections between the first and 28th of last [MONTH]?',
#                              'How many people were infected with Covid-19 last [MONTH]',
#                              'corona cases last [MONTH]']}},
#  {'question': 'covid deaths on the fith of May 2020',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Ludwigslust-Parchim District',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q2905',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'May',
#                    'PLACE_LABEL': 'Ludwigslust-Parchim District',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q2905',
#                    'QUESTION_CLASS': 'death_time',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_time'},
#                'questions': ['How many people died during [MONTH] [YEAR]?',
#                              'How many deaths were reported in [MONTH] of [YEAR]?',
#                              'covid deaths on the fith of [MONTH] [YEAR]',
#                              'What was the death toll during [MONTH] [YEAR]?',
#                              'number of deaths from first of [MONTH] until 15th of [MONTH] [YEAR]']}},
#  {'question': 'How many deaths were reported in Gotha in August 2021?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Gotha',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q7869',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'August',
#                    'PLACE_LABEL': 'Gotha',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q7869',
#                    'QUESTION_CLASS': 'death_location_time',
#                    'YEAR': 2021},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_location_time'},
#                'questions': ['What was the death toll in [PLACE_LABEL] during [MONTH] of [YEAR]?',
#                              'How many people died in [PLACE_LABEL] in [MONTH] [YEAR]?',
#                              'How many deaths were reported in [PLACE_LABEL] in [MONTH] [YEAR]?',
#                              'covid deaths in [PLACE_LABEL] in [MONTH] of [YEAR]',
#                              'how many deaths did [PLACE_LABEL] have in [MONTH] [YEAR]?']}},
#  {'question': 'How many people died during last April?',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Recklinghausen',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q6214',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'April',
#                    'PLACE_LABEL': 'Recklinghausen',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q6214',
#                    'QUESTION_CLASS': 'death_time',
#                    'YEAR': 2021},
#   'template': {'last': True,
#                'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_time'},
#                'questions': ['How many people died during last [MONTH]?',
#                              'How many deaths were reported in last [MONTH]?',
#                              'covid deaths on the fith of last [MONTH]',
#                              'What was the death toll last [MONTH]?',
#                              'number of deaths from the first until the 15th of last [MONTH]']}},
#  {'question': 'Infections in Segeberg and Kiel?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': False,
#                    'DISTRICT_LABEL': 'Segeberg',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q2980',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'March',
#                    'PLACE_LABEL': 'Segeberg',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q2980',
#                    'QUESTION_CLASS': 'infection_location',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': False, 'QUESTION_CLASS': 'infection_location'},
#                'questions': ['Infections in [PLACE_LABEL] and Kiel?',
#                              'Cases in [PLACE_LABEL]?',
#                              'How many people have been infected in [PLACE_LABEL] in total?',
#                              '[PLACE_LABEL] corona cases',
#                              'give me the number of infections in [PLACE_LABEL]']}},
#  {'question': 'Cases in Altmarkkreis Salzwedel?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': False,
#                    'DISTRICT_LABEL': 'Altmarkkreis Salzwedel',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q6061',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'March',
#                    'PLACE_LABEL': 'Altmarkkreis Salzwedel',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q6061',
#                    'QUESTION_CLASS': 'infection_location',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': False, 'QUESTION_CLASS': 'infection_location'},
#                'questions': ['Infections in [PLACE_LABEL] and Kiel?',
#                              'Cases in [PLACE_LABEL]?',
#                              'How many people have been infected in [PLACE_LABEL] in total?',
#                              '[PLACE_LABEL] corona cases',
#                              'give me the number of infections in [PLACE_LABEL]']}},
#  {'question': 'What was the death toll in Rhein-Wupper-Kreis during August of 2021?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Rhein-Wupper-Kreis',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q2147516',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'August',
#                    'PLACE_LABEL': 'Rhein-Wupper-Kreis',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q2147516',
#                    'QUESTION_CLASS': 'death_location_time',
#                    'YEAR': 2021},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_location_time'},
#                'questions': ['What was the death toll in [PLACE_LABEL] during [MONTH] of [YEAR]?',
#                              'How many people died in [PLACE_LABEL] in [MONTH] [YEAR]?',
#                              'How many deaths were reported in [PLACE_LABEL] in [MONTH] [YEAR]?',
#                              'covid deaths in [PLACE_LABEL] in [MONTH] of [YEAR]',
#                              'how many deaths did [PLACE_LABEL] have in [MONTH] [YEAR]?']}},
#  {'question': 'Cases in Ilm-Kreis?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': False,
#                    'DISTRICT_LABEL': 'Ilm-Kreis',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q7878',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'May',
#                    'PLACE_LABEL': 'Ilm-Kreis',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q7878',
#                    'QUESTION_CLASS': 'infection_location',
#                    'YEAR': 2021},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': False, 'QUESTION_CLASS': 'infection_location'},
#                'questions': ['Infections in [PLACE_LABEL] and Kiel?',
#                              'Cases in [PLACE_LABEL]?',
#                              'How many people have been infected in [PLACE_LABEL] in total?',
#                              '[PLACE_LABEL] corona cases',
#                              'give me the number of infections in [PLACE_LABEL]']}},
#  {'question': 'Infections in Marktheidenfeld and Kiel?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': False,
#                    'DISTRICT_LABEL': 'Marktheidenfeld',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q1803322',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'February',
#                    'PLACE_LABEL': 'Marktheidenfeld',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q1803322',
#                    'QUESTION_CLASS': 'infection_location',
#                    'YEAR': 2021},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': False, 'QUESTION_CLASS': 'infection_location'},
#                'questions': ['Infections in [PLACE_LABEL] and Kiel?',
#                              'Cases in [PLACE_LABEL]?',
#                              'How many people have been infected in [PLACE_LABEL] in total?',
#                              '[PLACE_LABEL] corona cases',
#                              'give me the number of infections in [PLACE_LABEL]']}},
#  {'question': 'What is the current death toll in Aichach?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': False,
#                    'DISTRICT_LABEL': 'Aichach',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q1756892',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'April',
#                    'PLACE_LABEL': 'Aichach',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q1756892',
#                    'QUESTION_CLASS': 'death_location',
#                    'YEAR': 2021},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': False, 'QUESTION_CLASS': 'death_location'},
#                'questions': ['How many people died in [PLACE_LABEL]?',
#                              'How many deaths were reported in [PLACE_LABEL]?',
#                              'covid deaths in [PLACE_LABEL]',
#                              'What is the current death toll in [PLACE_LABEL]?']}},
#  {'question': 'How many people were infected with Covid-19 last November',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Konstanz',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q8206',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'November',
#                    'PLACE_LABEL': 'Konstanz',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q8206',
#                    'QUESTION_CLASS': 'infection_time',
#                    'YEAR': 2020},
#   'template': {'last': True,
#                'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'infection_time'},
#                'questions': ['How many cases were reported on the first of last [MONTH]?',
#                              'What was the number of infections last [MONTH]?',
#                              'infections between the first and 28th of last [MONTH]?',
#                              'How many people were infected with Covid-19 last [MONTH]',
#                              'corona cases last [MONTH]']}},
#  {'question': 'covid deaths on the fith of last November',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'District of Erding',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q10539',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'November',
#                    'PLACE_LABEL': 'District of Erding',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q10539',
#                    'QUESTION_CLASS': 'death_time',
#                    'YEAR': 2020},
#   'template': {'last': True,
#                'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_time'},
#                'questions': ['How many people died during last [MONTH]?',
#                              'How many deaths were reported in last [MONTH]?',
#                              'covid deaths on the fith of last [MONTH]',
#                              'What was the death toll last [MONTH]?',
#                              'number of deaths from the first until the 15th of last [MONTH]']}},
#  {'question': 'How many deaths were reported last December in Rostock District?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Rostock District',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q2898',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'December',
#                    'PLACE_LABEL': 'Rostock District',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q2898',
#                    'QUESTION_CLASS': 'death_location_time',
#                    'YEAR': 2020},
#   'template': {'last': True,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_location_time'},
#                'questions': ['What was the death toll in [PLACE_LABEL] during the last [MONTH]?',
#                              'How many people died in [PLACE_LABEL] last [MONTH]?',
#                              'How many deaths were reported last [MONTH] in [PLACE_LABEL]?',
#                              'covid deaths in [PLACE_LABEL] last [MONTH]',
#                              'how many deaths did [PLACE_LABEL] have last [MONTH]?']}},
#  {'question': 'How many cases were reported on the first of September 2020?',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Schaumburg',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q5966',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'September',
#                    'PLACE_LABEL': 'Schaumburg',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q5966',
#                    'QUESTION_CLASS': 'infection_time',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'infection_time'},
#                'questions': ['How many cases were reported on the first of [MONTH] [YEAR]?',
#                              'What was the number of infections during [MONTH] [YEAR]?',
#                              'infections between the first of [MONTH] [YEAR] and the 28th of [MONTH] [YEAR]?',
#                              'How many people were infected with Covid-19 in [MONTH] [YEAR]',
#                              'corona cases in [MONTH] [YEAR]']}},
#  {'question': 'What is the current death toll in Mayen?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': False,
#                    'DISTRICT_LABEL': 'Mayen',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q1803325',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'December',
#                    'PLACE_LABEL': 'Mayen',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q1803325',
#                    'QUESTION_CLASS': 'death_location',
#                    'YEAR': 2021},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': False, 'QUESTION_CLASS': 'death_location'},
#                'questions': ['How many people died in [PLACE_LABEL]?',
#                              'How many deaths were reported in [PLACE_LABEL]?',
#                              'covid deaths in [PLACE_LABEL]',
#                              'What is the current death toll in [PLACE_LABEL]?']}},
#  {'question': 'In 2020, how many people were infected in Recklinghausen?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Recklinghausen',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q6214',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'March',
#                    'PLACE_LABEL': 'Recklinghausen',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q6214',
#                    'QUESTION_CLASS': 'infection_location_time',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True,
#                               'CONTAINS_TIME': True,
#                               'QUESTION_CLASS': 'infection_location_time'},
#                'questions': ['What was the number of incidents of [PLACE_LABEL] in [YEAR]?',
#                              'In [YEAR], how many people were infected in [PLACE_LABEL]?',
#                              'What was the number of infections during [YEAR] in [PLACE_LABEL]?']}},
#  {'question': 'In 2020, how many people were infected in Dahme-Spreewald District?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Dahme-Spreewald District',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q6173',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'June',
#                    'PLACE_LABEL': 'Dahme-Spreewald District',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q6173',
#                    'QUESTION_CLASS': 'infection_location_time',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True,
#                               'CONTAINS_TIME': True,
#                               'QUESTION_CLASS': 'infection_location_time'},
#                'questions': ['What was the number of incidents of [PLACE_LABEL] in [YEAR]?',
#                              'In [YEAR], how many people were infected in [PLACE_LABEL]?',
#                              'What was the number of infections during [YEAR] in [PLACE_LABEL]?']}},
#  {'question': 'How many deaths were reported in Annaberg in November 2020?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Annaberg',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q20221',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'November',
#                    'PLACE_LABEL': 'Annaberg',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q20221',
#                    'QUESTION_CLASS': 'death_location_time',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_location_time'},
#                'questions': ['What was the death toll in [PLACE_LABEL] during [MONTH] of [YEAR]?',
#                              'How many people died in [PLACE_LABEL] in [MONTH] [YEAR]?',
#                              'How many deaths were reported in [PLACE_LABEL] in [MONTH] [YEAR]?',
#                              'covid deaths in [PLACE_LABEL] in [MONTH] of [YEAR]',
#                              'how many deaths did [PLACE_LABEL] have in [MONTH] [YEAR]?']}},
#  {'question': 'In November 2021, how many people were infected in Altenkirchen district?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Altenkirchen district',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q8608',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'November',
#                    'PLACE_LABEL': 'Altenkirchen district',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q8608',
#                    'QUESTION_CLASS': 'infection_location_time',
#                    'YEAR': 2021},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True,
#                               'CONTAINS_TIME': True,
#                               'QUESTION_CLASS': 'infection_location_time'},
#                'questions': ['How many infections were there in [PLACE_LABEL] in [MONTH] [YEAR]?',
#                              'In [MONTH] [YEAR], how many people were infected in [PLACE_LABEL]?',
#                              'Give me the number of cases in [PLACE_LABEL] during [MONTH] [YEAR]!',
#                              'How many cases of Covid did [PLACE_LABEL] report in [MONTH] [YEAR]?',
#                              'infections in [MONTH] [YEAR] in [PLACE_LABEL]']}},
#  {'question': 'What is the current death toll in Hohenlohe?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': False,
#                    'DISTRICT_LABEL': 'Hohenlohe',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q8518',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'January',
#                    'PLACE_LABEL': 'Hohenlohe',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q8518',
#                    'QUESTION_CLASS': 'death_location',
#                    'YEAR': 2021},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': False, 'QUESTION_CLASS': 'death_location'},
#                'questions': ['How many people died in [PLACE_LABEL]?',
#                              'How many deaths were reported in [PLACE_LABEL]?',
#                              'covid deaths in [PLACE_LABEL]',
#                              'What is the current death toll in [PLACE_LABEL]?']}},
#  {'question': 'How many people were infected with Covid-19 in August 2020',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Vogtlandkreis',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q6337',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'August',
#                    'PLACE_LABEL': 'Vogtlandkreis',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q6337',
#                    'QUESTION_CLASS': 'infection_time',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'infection_time'},
#                'questions': ['How many cases were reported on the first of [MONTH] [YEAR]?',
#                              'What was the number of infections during [MONTH] [YEAR]?',
#                              'infections between the first of [MONTH] [YEAR] and the 28th of [MONTH] [YEAR]?',
#                              'How many people were infected with Covid-19 in [MONTH] [YEAR]',
#                              'corona cases in [MONTH] [YEAR]']}},
#  {'question': 'What was the number of infections during December 2021?',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Altenburger Land',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q7888',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'December',
#                    'PLACE_LABEL': 'Altenburger Land',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q7888',
#                    'QUESTION_CLASS': 'infection_time',
#                    'YEAR': 2021},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'infection_time'},
#                'questions': ['How many cases were reported on the first of [MONTH] [YEAR]?',
#                              'What was the number of infections during [MONTH] [YEAR]?',
#                              'infections between the first of [MONTH] [YEAR] and the 28th of [MONTH] [YEAR]?',
#                              'How many people were infected with Covid-19 in [MONTH] [YEAR]',
#                              'corona cases in [MONTH] [YEAR]']}},
#  {'question': 'how many deaths did Altlandkreis Lichtenfels have last March?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Altlandkreis Lichtenfels',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q105744572',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'March',
#                    'PLACE_LABEL': 'Altlandkreis Lichtenfels',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q105744572',
#                    'QUESTION_CLASS': 'death_location_time',
#                    'YEAR': 2020},
#   'template': {'last': True,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_location_time'},
#                'questions': ['What was the death toll in [PLACE_LABEL] during the last [MONTH]?',
#                              'How many people died in [PLACE_LABEL] last [MONTH]?',
#                              'How many deaths were reported last [MONTH] in [PLACE_LABEL]?',
#                              'covid deaths in [PLACE_LABEL] last [MONTH]',
#                              'how many deaths did [PLACE_LABEL] have last [MONTH]?']}},
#  {'question': 'corona cases in October 2020',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Herford',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q6234',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'October',
#                    'PLACE_LABEL': 'Herford',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q6234',
#                    'QUESTION_CLASS': 'infection_time',
#                    'YEAR': 2020},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'infection_time'},
#                'questions': ['How many cases were reported on the first of [MONTH] [YEAR]?',
#                              'What was the number of infections during [MONTH] [YEAR]?',
#                              'infections between the first of [MONTH] [YEAR] and the 28th of [MONTH] [YEAR]?',
#                              'How many people were infected with Covid-19 in [MONTH] [YEAR]',
#                              'corona cases in [MONTH] [YEAR]']}},
#  {'question': 'How many people died in Cochem-Zell?',
#   'replacements': {'CONTAINS_PLACE': True,
#                    'CONTAINS_TIME': False,
#                    'DISTRICT_LABEL': 'Cochem-Zell',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q8590',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'May',
#                    'PLACE_LABEL': 'Cochem-Zell',
#                    'PLACE_URL': 'http://www.wikidata.org/entity/Q8590',
#                    'QUESTION_CLASS': 'death_location',
#                    'YEAR': 2021},
#   'template': {'last': False,
#                'parameters': {'CONTAINS_PLACE': True, 'CONTAINS_TIME': False, 'QUESTION_CLASS': 'death_location'},
#                'questions': ['How many people died in [PLACE_LABEL]?',
#                              'How many deaths were reported in [PLACE_LABEL]?',
#                              'covid deaths in [PLACE_LABEL]',
#                              'What is the current death toll in [PLACE_LABEL]?']}},
#  {'question': 'number of deaths from the first until the 15th of last November',
#   'replacements': {'CONTAINS_PLACE': False,
#                    'CONTAINS_TIME': True,
#                    'DISTRICT_LABEL': 'Schmalkalden-Meiningen',
#                    'DISTRICT_URL': 'http://www.wikidata.org/entity/Q7871',
#                    'LANGUAGE': 'en',
#                    'MONTH': 'November',
#                    'PLACE_LABEL': 'Schmalkalden-Meiningen',
# ...
#                          'parameters': {'CONTAINS_PLACE': True,
#                                         'CONTAINS_TIME': True,
#                                         'QUESTION_CLASS': 'infection_location_time'},
#                          'questions': ['What was the number of incidents of [PLACE_LABEL] in [YEAR]?',
#                                        'In [YEAR], how many people were infected in [PLACE_LABEL]?',
#                                        'What was the number of infections during [YEAR] in [PLACE_LABEL]?']}},
#            {'question': 'infections between the first and 28th of last November?',
#             'replacements': {'CONTAINS_PLACE': False,
#                              'CONTAINS_TIME': True,
#                              'DISTRICT_LABEL': 'Trier-Saarburg',
#                              'DISTRICT_URL': 'http://www.wikidata.org/entity/Q8579',
#                              'LANGUAGE': 'en',
#                              'MONTH': 'November',
#                              'PLACE_LABEL': 'Trier-Saarburg',
#                              'PLACE_URL': 'http://www.wikidata.org/entity/Q8579',
#                              'QUESTION_CLASS': 'infection_time',
#                              'YEAR': 2021},
#             'template': {'last': True,
#                          'parameters': {'CONTAINS_PLACE': False,
#                                         'CONTAINS_TIME': True,
#                                         'QUESTION_CLASS': 'infection_time'},
#                          'questions': ['How many cases were reported on the first of last [MONTH]?',
#                                        'What was the number of infections last [MONTH]?',
#                                        'infections between the first and 28th of last [MONTH]?',
#                                        'How many people were infected with Covid-19 last [MONTH]',
#                                        'corona cases last [MONTH]']}},
#            {'question': 'What was the number of infections during January 2020?',
#             'replacements': {'CONTAINS_PLACE': False,
#                              'CONTAINS_TIME': True,
#                              'DISTRICT_LABEL': 'Delitzsch',
#                              'DISTRICT_URL': 'http://www.wikidata.org/entity/Q20230',
#                              'LANGUAGE': 'en',
#                              'MONTH': 'January',
#                              'PLACE_LABEL': 'Delitzsch',
#                              'PLACE_URL': 'http://www.wikidata.org/entity/Q20230',
#                              'QUESTION_CLASS': 'infection_time',
#                              'YEAR': 2020},
#             'template': {'last': False,
#                          'parameters': {'CONTAINS_PLACE': False,
#                                         'CONTAINS_TIME': True,
#                                         'QUESTION_CLASS': 'infection_time'},
#                          'questions': ['How many cases were reported on the first of [MONTH] [YEAR]?',
#                                        'What was the number of infections during [MONTH] [YEAR]?',
#                                        'infections between the first of [MONTH] [YEAR] and the 28th of [MONTH] [YEAR]?',
#                                        'How many people were infected with Covid-19 in [MONTH] [YEAR]',
#                                        'corona cases in [MONTH] [YEAR]']}},
#            {'question': 'give me the number of infections in Schweinfurt',
#             'replacements': {'CONTAINS_PLACE': True,
#                              'CONTAINS_TIME': False,
#                              'DISTRICT_LABEL': 'Schweinfurt',
#                              'DISTRICT_URL': 'http://www.wikidata.org/entity/Q10461',
#                              'LANGUAGE': 'en',
#                              'MONTH': 'October',
#                              'PLACE_LABEL': 'Schweinfurt',
#                              'PLACE_URL': 'http://www.wikidata.org/entity/Q10461',
#                              'QUESTION_CLASS': 'infection_location',
#                              'YEAR': 2020},
#             'template': {'last': False,
#                          'parameters': {'CONTAINS_PLACE': True,
#                                         'CONTAINS_TIME': False,
#                                         'QUESTION_CLASS': 'infection_location'},
#                          'questions': ['Infections in [PLACE_LABEL] and Kiel?',
#                                        'Cases in [PLACE_LABEL]?',
#                                        'How many people have been infected in [PLACE_LABEL] in total?',
#                                        '[PLACE_LABEL] corona cases',
#                                        'give me the number of infections in [PLACE_LABEL]']}},
#            {'question': 'What was the number of incidents of Nordfriesland district in 2020?',
#             'replacements': {'CONTAINS_PLACE': True,
#                              'CONTAINS_TIME': True,
#                              'DISTRICT_LABEL': 'Nordfriesland district',
#                              'DISTRICT_URL': 'http://www.wikidata.org/entity/Q2937',
#                              'LANGUAGE': 'en',
#                              'MONTH': 'August',
#                              'PLACE_LABEL': 'Nordfriesland district',
#                              'PLACE_URL': 'http://www.wikidata.org/entity/Q2937',
#                              'QUESTION_CLASS': 'infection_location_time',
#                              'YEAR': 2020},
#             'template': {'last': False,
#                          'parameters': {'CONTAINS_PLACE': True,
#                                         'CONTAINS_TIME': True,
#                                         'QUESTION_CLASS': 'infection_location_time'},
#                          'questions': ['What was the number of incidents of [PLACE_LABEL] in [YEAR]?',
#                                        'In [YEAR], how many people were infected in [PLACE_LABEL]?',
#                                        'What was the number of infections during [YEAR] in [PLACE_LABEL]?']}},
#            {'question': 'What was the number of infections last October?',
#             'replacements': {'CONTAINS_PLACE': False,
#                              'CONTAINS_TIME': True,
#                              'DISTRICT_LABEL': 'Wesermarsch',
#                              'DISTRICT_URL': 'http://www.wikidata.org/entity/Q5948',
#                              'LANGUAGE': 'en',
#                              'MONTH': 'October',
#                              'PLACE_LABEL': 'Wesermarsch',
#                              'PLACE_URL': 'http://www.wikidata.org/entity/Q5948',
#                              'QUESTION_CLASS': 'infection_time',
#                              'YEAR': 2020},
#             'template': {'last': True,
#                          'parameters': {'CONTAINS_PLACE': False,
#                                         'CONTAINS_TIME': True,
#                                         'QUESTION_CLASS': 'infection_time'},
#                          'questions': ['How many cases were reported on the first of last [MONTH]?',
#                                        'What was the number of infections last [MONTH]?',
#                                        'infections between the first and 28th of last [MONTH]?',
#                                        'How many people were infected with Covid-19 last [MONTH]',
#                                        'corona cases last [MONTH]']}},
#            {'question': 'How many deaths were reported last June in Märkisch-Oderland District?',
#             'replacements': {'CONTAINS_PLACE': True,
#                              'CONTAINS_TIME': True,
#                              'DISTRICT_LABEL': 'Märkisch-Oderland District',
#                              'DISTRICT_URL': 'http://www.wikidata.org/entity/Q6181',
#                              'LANGUAGE': 'en',
#                              'MONTH': 'June',
#                              'PLACE_LABEL': 'Märkisch-Oderland District',
#                              'PLACE_URL': 'http://www.wikidata.org/entity/Q6181',
#                              'QUESTION_CLASS': 'death_location_time',
#                              'YEAR': 2020},
#             'template': {'last': True,
#                          'parameters': {'CONTAINS_PLACE': True,
#                                         'CONTAINS_TIME': True,
#                                         'QUESTION_CLASS': 'death_location_time'},
#                          'questions': ['What was the death toll in [PLACE_LABEL] during the last [MONTH]?',
#                                        'How many people died in [PLACE_LABEL] last [MONTH]?',
#                                        'How many deaths were reported last [MONTH] in [PLACE_LABEL]?',
#                                        'covid deaths in [PLACE_LABEL] last [MONTH]',
#                                        'how many deaths did [PLACE_LABEL] have last [MONTH]?']}},
#            {'question': 'How many deaths were reported in July of 2020?',
#             'replacements': {'CONTAINS_PLACE': False,
#                              'CONTAINS_TIME': True,
#                              'DISTRICT_LABEL': 'Vorpommern-Greifswald District',
#                              'DISTRICT_URL': 'http://www.wikidata.org/entity/Q2917',
#                              'LANGUAGE': 'en',
#                              'MONTH': 'July',
#                              'PLACE_LABEL': 'Vorpommern-Greifswald District',
#                              'PLACE_URL': 'http://www.wikidata.org/entity/Q2917',
#                              'QUESTION_CLASS': 'death_time',
#                              'YEAR': 2020},
#             'template': {'last': False,
#                          'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_time'},
#                          'questions': ['How many people died during [MONTH] [YEAR]?',
#                                        'How many deaths were reported in [MONTH] of [YEAR]?',
#                                        'covid deaths on the fith of [MONTH] [YEAR]',
#                                        'What was the death toll during [MONTH] [YEAR]?',
#                                        'number of deaths from first of [MONTH] until 15th of [MONTH] [YEAR]']}},
#            {'question': 'What was the death toll during December 2020?',
#             'replacements': {'CONTAINS_PLACE': False,
#                              'CONTAINS_TIME': True,
#                              'DISTRICT_LABEL': 'Rees District',
#                              'DISTRICT_URL': 'http://www.wikidata.org/entity/Q1759911',
#                              'LANGUAGE': 'en',
#                              'MONTH': 'December',
#                              'PLACE_LABEL': 'Rees District',
#                              'PLACE_URL': 'http://www.wikidata.org/entity/Q1759911',
#                              'QUESTION_CLASS': 'death_time',
#                              'YEAR': 2020},
#             'template': {'last': False,
#                          'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_time'},
#                          'questions': ['How many people died during [MONTH] [YEAR]?',
#                                        'How many deaths were reported in [MONTH] of [YEAR]?',
#                                        'covid deaths on the fith of [MONTH] [YEAR]',
#                                        'What was the death toll during [MONTH] [YEAR]?',
#                                        'number of deaths from first of [MONTH] until 15th of [MONTH] [YEAR]']}},
#            {'question': 'What was the death toll during February 2020?',
#             'replacements': {'CONTAINS_PLACE': False,
#                              'CONTAINS_TIME': True,
#                              'DISTRICT_LABEL': 'Waldshut',
#                              'DISTRICT_URL': 'http://www.wikidata.org/entity/Q8200',
#                              'LANGUAGE': 'en',
#                              'MONTH': 'February',
#                              'PLACE_LABEL': 'Waldshut',
#                              'PLACE_URL': 'http://www.wikidata.org/entity/Q8200',
#                              'QUESTION_CLASS': 'death_time',
#                              'YEAR': 2020},
#             'template': {'last': False,
#                          'parameters': {'CONTAINS_PLACE': False, 'CONTAINS_TIME': True, 'QUESTION_CLASS': 'death_time'},
#                          'questions': ['How many people died during [MONTH] [YEAR]?',
#                                        'How many deaths were reported in [MONTH] of [YEAR]?',
#                                        'covid deaths on the fith of [MONTH] [YEAR]',
#                                        'What was the death toll during [MONTH] [YEAR]?',
#                                        'number of deaths from first of [MONTH] until 15th of [MONTH] [YEAR]']}},
#            {'question': 'Infections in Deggendorf and Kiel?',
#             'replacements': {'CONTAINS_PLACE': True,
#                              'CONTAINS_TIME': False,
#                              'DISTRICT_LABEL': 'Deggendorf',
#                              'DISTRICT_URL': 'http://www.wikidata.org/entity/Q10485',
#                              'LANGUAGE': 'en',
#                              'MONTH': 'September',
#                              'PLACE_LABEL': 'Deggendorf',
#                              'PLACE_URL': 'http://www.wikidata.org/entity/Q10485',
#                              'QUESTION_CLASS': 'infection_location',
#                              'YEAR': 2021},
#             'template': {'last': False,
#                          'parameters': {'CONTAINS_PLACE': True,
#                                         'CONTAINS_TIME': False,
#                                         'QUESTION_CLASS': 'infection_location'},
#                          'questions': ['Infections in [PLACE_LABEL] and Kiel?',
#                                        'Cases in [PLACE_LABEL]?',
#                                        'How many people have been infected in [PLACE_LABEL] in total?',
#                                        '[PLACE_LABEL] corona cases',
#                                        'give me the number of infections in [PLACE_LABEL]']}},
#            {'question': 'What was the number of infections during August 2020?',
#             'replacements': {'CONTAINS_PLACE': False,
#                              'CONTAINS_TIME': True,
#                              'DISTRICT_LABEL': 'Dieburg',
#                              'DISTRICT_URL': 'http://www.wikidata.org/entity/Q1803125',
#                              'LANGUAGE': 'en',
#                              'MONTH': 'August',
#                              'PLACE_LABEL': 'Dieburg',
#                              'PLACE_URL': 'http://www.wikidata.org/entity/Q1803125',
#                              'QUESTION_CLASS': 'infection_time',
#                              'YEAR': 2020},
#             'template': {'last': False,
#                          'parameters': {'CONTAINS_PLACE': False,
#                                         'CONTAINS_TIME': True,
#                                         'QUESTION_CLASS': 'infection_time'},
#                          'questions': ['How many cases were reported on the first of [MONTH] [YEAR]?',
#                                        'What was the number of infections during [MONTH] [YEAR]?',
#                                        'infections between the first of [MONTH] [YEAR] and the 28th of [MONTH] [YEAR]?',
#                                        'How many people were infected with Covid-19 in [MONTH] [YEAR]',
#                                        'corona cases in [MONTH] [YEAR]']}}],
#  'validation-sparql-templates': ['01_language_detection.sparql',
#                                  '02_question_classification.sparql',
#                                  '03_time_recognition.sparql',
#                                  '04_ned.sparql',
#                                  '05_location_to_german_district.sparql',
#                                  '06_coronabot_missing_information.sparql',
#                                  '07_rki_query.sparql']}
# number of questions:  500

# %% [markdown]
# # Output to file

# %%
import json 

with open('sparql_test_query_templates/qanary-test-definition.json', 'w') as outfile:
    json.dump(generated_configuration, outfile, indent=4)
